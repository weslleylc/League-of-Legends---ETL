# %%
from pyspark.sql import SparkSession
from pyspark.sql import SQLContext
from pyspark.sql.functions import udf, explode, flatten, explode_outer
from pyspark.sql.types import ArrayType, IntegerType, StringType, StructType, StructField, DoubleType, LongType, MapType, BooleanType
from pyspark.sql import functions as F
from pyspark.sql import Row
from pyspark.sql.functions import col, concat
import json

# %% [markdown]
# # Start Spark Session

# %%
spark = SparkSession.builder.appName('lol').master("local").getOrCreate()
sqlContext = SQLContext(spark)

# %% [markdown]
# # EXTRACT DATA

# %% [markdown]
# # Define initial Schema

# %%
match_schema = StructType(
    [
        StructField('_c0', IntegerType(), True),
        StructField('gameCreation', DoubleType(), True),
        StructField('gameDuration', DoubleType(), True),
        StructField('gameId', DoubleType(), True),
        StructField('gameMode', StringType(), True),
        StructField('gameType', StringType(), True),
        StructField('gameVersion', StringType(), True),
        StructField('mapId', DoubleType(), True),
        StructField('participantIdentities', StringType(), True),
        StructField('participants',  StringType(), True),
        StructField('platformId', StringType(), True),
        StructField('queueId', DoubleType(), True),
        StructField('seasonId', DoubleType(), True),
        StructField('status.message', StringType(), True),
        StructField('status.status_code', StringType(), True)
    ]
)

loser_winner_schema = StructType(
    [
        StructField('_c0', IntegerType(), True),
        StructField('teamId', IntegerType(), True),
        StructField('win', StringType(), True),
        StructField('firstBlood', BooleanType(), True),
        StructField('firstTower', BooleanType(), True),
        StructField('firstInhibitor', BooleanType(), True),
        StructField('firstBaron', BooleanType(), True),
        StructField('firstDragon', BooleanType(), True),
        StructField('firstRiftHerald', BooleanType(), True),
        StructField('towerKills',  IntegerType(), True),
        StructField('inhibitorKills', IntegerType(), True),
        StructField('baronKills', IntegerType(), True),
        StructField('dragonKills', IntegerType(), True),
        StructField('vilemawKills', IntegerType(), True),
        StructField('riftHeraldKills', IntegerType(), True),
        StructField('dominionVictoryScore', IntegerType(), True),
        StructField('bans', StringType()),
        StructField('gameId', DoubleType(), True)

    ]
)


itens_schema = StructType(
    [
        StructField('_c0', IntegerType(), True),
        StructField('item_id', IntegerType(), True),
        StructField('name', StringType(), True),
        StructField('upper_item', StringType(), True),
        StructField('explain', StringType(), True),
        StructField('buy_price', IntegerType(), True),
        StructField('sell_price', IntegerType(), True),
        StructField('tag', StringType(), True)
    ]
)

# %%
# read match data
match_data = spark.read.csv("../data/match_data_version1.csv",
                    header='true',
                    schema=match_schema)
match_data = match_data.sample(False, 0.1, seed=0)

itens = spark.read.csv("../data/riot_item.csv",
                    header='true',
                    schema=itens_schema)

champions = spark.read.csv("../data/riot_champion.csv",
                    header='true',
                    inferSchema=True)


# read winner and loser match dadas
# winner and losser files uses the same schema
loser = spark.read.csv("../data/match_loser_data_version1.csv",
                    header='true',
                    schema=loser_winner_schema)
winner = spark.read.csv("../data/match_winner_data_version1.csv",
                    header='true',
                    schema=loser_winner_schema)

# %%
champions.printSchema()
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- version: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- key: integer (nullable = true)
#  |-- name: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- blurb: string (nullable = true)
#  |-- tags: string (nullable = true)
#  |-- partype: string (nullable = true)
#  |-- info.attack: integer (nullable = true)
#  |-- info.defense: integer (nullable = true)
#  |-- info.magic: integer (nullable = true)
#  |-- info.difficulty: integer (nullable = true)
#  |-- image.full: string (nullable = true)
#  |-- image.sprite: string (nullable = true)
#  |-- image.group: string (nullable = true)
#  |-- image.x: integer (nullable = true)
#  |-- image.y: integer (nullable = true)
#  |-- image.w: integer (nullable = true)
#  |-- image.h: integer (nullable = true)
#  |-- stats.hp: double (nullable = true)
#  |-- stats.hpperlevel: integer (nullable = true)
#  |-- stats.mp: double (nullable = true)
#  |-- stats.mpperlevel: double (nullable = true)
#  |-- stats.movespeed: integer (nullable = true)
#  |-- stats.armor: double (nullable = true)
#  |-- stats.armorperlevel: double (nullable = true)
#  |-- stats.spellblock: double (nullable = true)
#  |-- stats.spellblockperlevel: double (nullable = true)
#  |-- stats.attackrange: integer (nullable = true)
#  |-- stats.hpregen: double (nullable = true)
#  |-- stats.hpregenperlevel: double (nullable = true)
#  |-- stats.mpregen: double (nullable = true)
#  |-- stats.mpregenperlevel: double (nullable = true)
#  |-- stats.crit: integer (nullable = true)
#  |-- stats.critperlevel: integer (nullable = true)
#  |-- stats.attackdamage: double (nullable = true)
#  |-- stats.attackdamageperlevel: double (nullable = true)
#  |-- stats.attackspeedperlevel: double (nullable = true)
#  |-- stats.attackspeed: double (nullable = true)

# %% [markdown]
# # Transform

# %% [markdown]
# Let`s define some utility functions.

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *
import pyspark.sql.functions as F

# Convenience function for turning JSON strings into DataFrames.
# https://docs.databricks.com/_static/notebooks/transform-complex-data-types-scala.html
def jsonToDataFrame(json_input, schema=None):
    # SparkSessions are available with Spark 2.0+
    reader = spark.read
    if schema:
        reader.schema(schema)
    return reader.json(sc.parallelize([json_input]))


# Convenience function flatten dataframes with structs.
#https://stackoverflow.com/questions/38753898/how-to-flatten-a-struct-in-a-spark-dataframe
def flatten_df(nested_df):
    stack = [((), nested_df)]
    columns = []

    while len(stack) > 0:
        parents, df = stack.pop()

        flat_cols = [
            col(".".join(parents + (c[0],))).alias("_".join(parents + (c[0],)))
            for c in df.dtypes
            if c[1][:6] != "struct"
        ]

        nested_cols = [
            c[0]
            for c in df.dtypes
            if c[1][:6] == "struct"
        ]

        columns.extend(flat_cols)

        for nested_col in nested_cols:
            projected_df = df.select(nested_col + ".*")
            stack.append((parents + (nested_col,), projected_df))

    return nested_df.select(columns)

# %% [markdown]
# ## Extract new schema for loser and winner data

# %%
#convert the dict string into json string
convert_json_string = udf(lambda colum: "{"+",".join([('"'+"championId" + str(x["pickTurn"]))+'"'+":" +str(x["championId"])+"" for x in eval(colum)])  +"}", StringType())
loser = loser.withColumn("bans", convert_json_string(loser.bans))

# %% [markdown]
# ### Get schema from first row

# %%
# get the first row and transform into pyspark Dataframe, then extract the schema
bans_schema = jsonToDataFrame(loser.select(loser.bans).take(1)[0].asDict()["bans"]).schema

# %%
# applay the extracted schema to all rows
eval_column_bans = udf(lambda x : eval(x), bans_schema)

loser = loser.withColumn('bans', eval_column_bans(loser.bans))
winner = winner.withColumn('bans', eval_column_bans(winner.bans))

# %%
loser = flatten_df(loser)
winner = flatten_df(winner)

# %%
loser.printSchema()
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- teamId: integer (nullable = true)
#  |-- win: string (nullable = true)
#  |-- firstBlood: boolean (nullable = true)
#  |-- firstTower: boolean (nullable = true)
#  |-- firstInhibitor: boolean (nullable = true)
#  |-- firstBaron: boolean (nullable = true)
#  |-- firstDragon: boolean (nullable = true)
#  |-- firstRiftHerald: boolean (nullable = true)
#  |-- towerKills: integer (nullable = true)
#  |-- inhibitorKills: integer (nullable = true)
#  |-- baronKills: integer (nullable = true)
#  |-- dragonKills: integer (nullable = true)
#  |-- vilemawKills: integer (nullable = true)
#  |-- riftHeraldKills: integer (nullable = true)
#  |-- dominionVictoryScore: integer (nullable = true)
#  |-- gameId: double (nullable = true)
#  |-- bans_championId1: long (nullable = true)
#  |-- bans_championId2: long (nullable = true)
#  |-- bans_championId3: long (nullable = true)
#  |-- bans_championId4: long (nullable = true)
#  |-- bans_championId5: long (nullable = true)

# %% [markdown]
# ## Extract new schema for match data

# %%
# Rename columns with '.'
match_data = match_data.withColumnRenamed("status.message", "status_message")
match_data = match_data.withColumnRenamed("status.status_code", "status_status_code")

# %% [markdown]
# get first row of participants, convert into json, then converti into dataframe and then extract the schema

# %%
participants = match_data.select(match_data.participants)
str_participants = participants.take(1)[0].asDict()["participants"]
participants = jsonToDataFrame(json.dumps(eval(str_participants)))
schema = participants.schema

# %%
participants = match_data.select(match_data.participantIdentities)
str_participantIdentities = participants.take(1)[0].asDict()["participantIdentities"]
participants = jsonToDataFrame(json.dumps(eval(str_participantIdentities)))
schema_participantIdentities = participants.schema

# %%
eval_column_participants = udf(lambda x : eval(x), ArrayType(schema))

match_data = match_data.withColumn('participants', eval_column_participants(match_data.participants))

# %%
eval_column_schema_participantIdentities = udf(lambda x : eval(x), ArrayType(schema_participantIdentities))

match_data = match_data.withColumn('participantIdentities', eval_column_schema_participantIdentities(match_data.participantIdentities))

# %%
# new schema
match_data.printSchema()
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- gameCreation: double (nullable = true)
#  |-- gameDuration: double (nullable = true)
#  |-- gameId: double (nullable = true)
#  |-- gameMode: string (nullable = true)
#  |-- gameType: string (nullable = true)
#  |-- gameVersion: string (nullable = true)
#  |-- mapId: double (nullable = true)
#  |-- participantIdentities: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- participantId: long (nullable = true)
#  |    |    |-- player: struct (nullable = true)
#  |    |    |    |-- accountId: string (nullable = true)
#  |    |    |    |-- currentAccountId: string (nullable = true)
#  |    |    |    |-- currentPlatformId: string (nullable = true)
#  |    |    |    |-- matchHistoryUri: string (nullable = true)
#  |    |    |    |-- platformId: string (nullable = true)
#  |    |    |    |-- profileIcon: long (nullable = true)
#  |    |    |    |-- summonerId: string (nullable = true)
#  |    |    |    |-- summonerName: string (nullable = true)
#  |-- participants: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- championId: long (nullable = true)
#  |    |    |-- participantId: long (nullable = true)
#  |    |    |-- spell1Id: long (nullable = true)
#  |    |    |-- spell2Id: long (nullable = true)
#  |    |    |-- stats: struct (nullable = true)
#  |    |    |    |-- assists: long (nullable = true)
#  |    |    |    |-- champLevel: long (nullable = true)
#  |    |    |    |-- combatPlayerScore: long (nullable = true)
#  |    |    |    |-- damageDealtToObjectives: long (nullable = true)
#  |    |    |    |-- damageDealtToTurrets: long (nullable = true)
#  |    |    |    |-- damageSelfMitigated: long (nullable = true)
#  |    |    |    |-- deaths: long (nullable = true)
#  |    |    |    |-- doubleKills: long (nullable = true)
#  |    |    |    |-- firstBloodAssist: boolean (nullable = true)
#  |    |    |    |-- firstBloodKill: boolean (nullable = true)
#  |    |    |    |-- firstTowerAssist: boolean (nullable = true)
#  |    |    |    |-- firstTowerKill: boolean (nullable = true)
#  |    |    |    |-- goldEarned: long (nullable = true)
#  |    |    |    |-- goldSpent: long (nullable = true)
#  |    |    |    |-- inhibitorKills: long (nullable = true)
#  |    |    |    |-- item0: long (nullable = true)
#  |    |    |    |-- item1: long (nullable = true)
#  |    |    |    |-- item2: long (nullable = true)
#  |    |    |    |-- item3: long (nullable = true)
#  |    |    |    |-- item4: long (nullable = true)
#  |    |    |    |-- item5: long (nullable = true)
#  |    |    |    |-- item6: long (nullable = true)
#  |    |    |    |-- killingSprees: long (nullable = true)
#  |    |    |    |-- kills: long (nullable = true)
#  |    |    |    |-- largestCriticalStrike: long (nullable = true)
#  |    |    |    |-- largestKillingSpree: long (nullable = true)
#  |    |    |    |-- largestMultiKill: long (nullable = true)
#  |    |    |    |-- longestTimeSpentLiving: long (nullable = true)
#  |    |    |    |-- magicDamageDealt: long (nullable = true)
#  |    |    |    |-- magicDamageDealtToChampions: long (nullable = true)
#  |    |    |    |-- magicalDamageTaken: long (nullable = true)
#  |    |    |    |-- neutralMinionsKilled: long (nullable = true)
#  |    |    |    |-- neutralMinionsKilledEnemyJungle: long (nullable = true)
#  |    |    |    |-- neutralMinionsKilledTeamJungle: long (nullable = true)
#  |    |    |    |-- objectivePlayerScore: long (nullable = true)
#  |    |    |    |-- participantId: long (nullable = true)
#  |    |    |    |-- pentaKills: long (nullable = true)
#  |    |    |    |-- perk0: long (nullable = true)
#  |    |    |    |-- perk0Var1: long (nullable = true)
#  |    |    |    |-- perk0Var2: long (nullable = true)
#  |    |    |    |-- perk0Var3: long (nullable = true)
#  |    |    |    |-- perk1: long (nullable = true)
#  |    |    |    |-- perk1Var1: long (nullable = true)
#  |    |    |    |-- perk1Var2: long (nullable = true)
#  |    |    |    |-- perk1Var3: long (nullable = true)
#  |    |    |    |-- perk2: long (nullable = true)
#  |    |    |    |-- perk2Var1: long (nullable = true)
#  |    |    |    |-- perk2Var2: long (nullable = true)
#  |    |    |    |-- perk2Var3: long (nullable = true)
#  |    |    |    |-- perk3: long (nullable = true)
#  |    |    |    |-- perk3Var1: long (nullable = true)
#  |    |    |    |-- perk3Var2: long (nullable = true)
#  |    |    |    |-- perk3Var3: long (nullable = true)
#  |    |    |    |-- perk4: long (nullable = true)
#  |    |    |    |-- perk4Var1: long (nullable = true)
#  |    |    |    |-- perk4Var2: long (nullable = true)
#  |    |    |    |-- perk4Var3: long (nullable = true)
#  |    |    |    |-- perk5: long (nullable = true)
#  |    |    |    |-- perk5Var1: long (nullable = true)
#  |    |    |    |-- perk5Var2: long (nullable = true)
#  |    |    |    |-- perk5Var3: long (nullable = true)
#  |    |    |    |-- perkPrimaryStyle: long (nullable = true)
#  |    |    |    |-- perkSubStyle: long (nullable = true)
#  |    |    |    |-- physicalDamageDealt: long (nullable = true)
#  |    |    |    |-- physicalDamageDealtToChampions: long (nullable = true)
#  |    |    |    |-- physicalDamageTaken: long (nullable = true)
#  |    |    |    |-- playerScore0: long (nullable = true)
#  |    |    |    |-- playerScore1: long (nullable = true)
#  |    |    |    |-- playerScore2: long (nullable = true)
#  |    |    |    |-- playerScore3: long (nullable = true)
#  |    |    |    |-- playerScore4: long (nullable = true)
#  |    |    |    |-- playerScore5: long (nullable = true)
#  |    |    |    |-- playerScore6: long (nullable = true)
#  |    |    |    |-- playerScore7: long (nullable = true)
#  |    |    |    |-- playerScore8: long (nullable = true)
#  |    |    |    |-- playerScore9: long (nullable = true)
#  |    |    |    |-- quadraKills: long (nullable = true)
#  |    |    |    |-- sightWardsBoughtInGame: long (nullable = true)
#  |    |    |    |-- statPerk0: long (nullable = true)
#  |    |    |    |-- statPerk1: long (nullable = true)
#  |    |    |    |-- statPerk2: long (nullable = true)
#  |    |    |    |-- timeCCingOthers: long (nullable = true)
#  |    |    |    |-- totalDamageDealt: long (nullable = true)
#  |    |    |    |-- totalDamageDealtToChampions: long (nullable = true)
#  |    |    |    |-- totalDamageTaken: long (nullable = true)
#  |    |    |    |-- totalHeal: long (nullable = true)
#  |    |    |    |-- totalMinionsKilled: long (nullable = true)
#  |    |    |    |-- totalPlayerScore: long (nullable = true)
#  |    |    |    |-- totalScoreRank: long (nullable = true)
#  |    |    |    |-- totalTimeCrowdControlDealt: long (nullable = true)
#  |    |    |    |-- totalUnitsHealed: long (nullable = true)
#  |    |    |    |-- tripleKills: long (nullable = true)
#  |    |    |    |-- trueDamageDealt: long (nullable = true)
#  |    |    |    |-- trueDamageDealtToChampions: long (nullable = true)
#  |    |    |    |-- trueDamageTaken: long (nullable = true)
#  |    |    |    |-- turretKills: long (nullable = true)
#  |    |    |    |-- unrealKills: long (nullable = true)
#  |    |    |    |-- visionScore: long (nullable = true)
#  |    |    |    |-- visionWardsBoughtInGame: long (nullable = true)
#  |    |    |    |-- wardsKilled: long (nullable = true)
#  |    |    |    |-- wardsPlaced: long (nullable = true)
#  |    |    |    |-- win: boolean (nullable = true)
#  |    |    |-- teamId: long (nullable = true)
#  |    |    |-- timeline: struct (nullable = true)
#  |    |    |    |-- creepsPerMinDeltas: struct (nullable = true)
#  |    |    |    |    |-- 0-10: double (nullable = true)
#  |    |    |    |    |-- 10-20: double (nullable = true)
#  |    |    |    |-- csDiffPerMinDeltas: struct (nullable = true)
#  |    |    |    |    |-- 0-10: double (nullable = true)
#  |    |    |    |    |-- 10-20: double (nullable = true)
#  |    |    |    |-- damageTakenDiffPerMinDeltas: struct (nullable = true)
#  |    |    |    |    |-- 0-10: double (nullable = true)
#  |    |    |    |    |-- 10-20: double (nullable = true)
#  |    |    |    |-- damageTakenPerMinDeltas: struct (nullable = true)
#  |    |    |    |    |-- 0-10: double (nullable = true)
#  |    |    |    |    |-- 10-20: double (nullable = true)
#  |    |    |    |-- goldPerMinDeltas: struct (nullable = true)
#  |    |    |    |    |-- 0-10: double (nullable = true)
#  |    |    |    |    |-- 10-20: double (nullable = true)
#  |    |    |    |-- lane: string (nullable = true)
#  |    |    |    |-- participantId: long (nullable = true)
#  |    |    |    |-- role: string (nullable = true)
#  |    |    |    |-- xpDiffPerMinDeltas: struct (nullable = true)
#  |    |    |    |    |-- 0-10: double (nullable = true)
#  |    |    |    |    |-- 10-20: double (nullable = true)
#  |    |    |    |-- xpPerMinDeltas: struct (nullable = true)
#  |    |    |    |    |-- 0-10: double (nullable = true)
#  |    |    |    |    |-- 10-20: double (nullable = true)
#  |-- platformId: string (nullable = true)
#  |-- queueId: double (nullable = true)
#  |-- seasonId: double (nullable = true)
#  |-- status_message: string (nullable = true)
#  |-- status_status_code: string (nullable = true)

# %%
combine = udf(lambda x, y: list(zip(x, y)),ArrayType(StructType([StructField("ids", schema),
                                    StructField("info", schema_participantIdentities)]))
             )
match_data = match_data.withColumn("participants_info", combine("participants", "participantIdentities"))

# %%
columns_to_drop = ['participants', 'participantIdentities']
match_data = match_data.drop(*columns_to_drop)
match_data = match_data.withColumn("participants_info", explode("participants_info"))

# %%
match_data.printSchema()
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- gameCreation: double (nullable = true)
#  |-- gameDuration: double (nullable = true)
#  |-- gameId: double (nullable = true)
#  |-- gameMode: string (nullable = true)
#  |-- gameType: string (nullable = true)
#  |-- gameVersion: string (nullable = true)
#  |-- mapId: double (nullable = true)
#  |-- platformId: string (nullable = true)
#  |-- queueId: double (nullable = true)
#  |-- seasonId: double (nullable = true)
#  |-- status_message: string (nullable = true)
#  |-- status_status_code: string (nullable = true)
#  |-- participants_info: struct (nullable = true)
#  |    |-- ids: struct (nullable = true)
#  |    |    |-- championId: long (nullable = true)
#  |    |    |-- participantId: long (nullable = true)
#  |    |    |-- spell1Id: long (nullable = true)
#  |    |    |-- spell2Id: long (nullable = true)
#  |    |    |-- stats: struct (nullable = true)
#  |    |    |    |-- assists: long (nullable = true)
#  |    |    |    |-- champLevel: long (nullable = true)
#  |    |    |    |-- combatPlayerScore: long (nullable = true)
#  |    |    |    |-- damageDealtToObjectives: long (nullable = true)
#  |    |    |    |-- damageDealtToTurrets: long (nullable = true)
#  |    |    |    |-- damageSelfMitigated: long (nullable = true)
#  |    |    |    |-- deaths: long (nullable = true)
#  |    |    |    |-- doubleKills: long (nullable = true)
#  |    |    |    |-- firstBloodAssist: boolean (nullable = true)
#  |    |    |    |-- firstBloodKill: boolean (nullable = true)
#  |    |    |    |-- firstTowerAssist: boolean (nullable = true)
#  |    |    |    |-- firstTowerKill: boolean (nullable = true)
#  |    |    |    |-- goldEarned: long (nullable = true)
#  |    |    |    |-- goldSpent: long (nullable = true)
#  |    |    |    |-- inhibitorKills: long (nullable = true)
#  |    |    |    |-- item0: long (nullable = true)
#  |    |    |    |-- item1: long (nullable = true)
#  |    |    |    |-- item2: long (nullable = true)
#  |    |    |    |-- item3: long (nullable = true)
#  |    |    |    |-- item4: long (nullable = true)
#  |    |    |    |-- item5: long (nullable = true)
#  |    |    |    |-- item6: long (nullable = true)
#  |    |    |    |-- killingSprees: long (nullable = true)
#  |    |    |    |-- kills: long (nullable = true)
#  |    |    |    |-- largestCriticalStrike: long (nullable = true)
#  |    |    |    |-- largestKillingSpree: long (nullable = true)
#  |    |    |    |-- largestMultiKill: long (nullable = true)
#  |    |    |    |-- longestTimeSpentLiving: long (nullable = true)
#  |    |    |    |-- magicDamageDealt: long (nullable = true)
#  |    |    |    |-- magicDamageDealtToChampions: long (nullable = true)
#  |    |    |    |-- magicalDamageTaken: long (nullable = true)
#  |    |    |    |-- neutralMinionsKilled: long (nullable = true)
#  |    |    |    |-- neutralMinionsKilledEnemyJungle: long (nullable = true)
#  |    |    |    |-- neutralMinionsKilledTeamJungle: long (nullable = true)
#  |    |    |    |-- objectivePlayerScore: long (nullable = true)
#  |    |    |    |-- participantId: long (nullable = true)
#  |    |    |    |-- pentaKills: long (nullable = true)
#  |    |    |    |-- perk0: long (nullable = true)
#  |    |    |    |-- perk0Var1: long (nullable = true)
#  |    |    |    |-- perk0Var2: long (nullable = true)
#  |    |    |    |-- perk0Var3: long (nullable = true)
#  |    |    |    |-- perk1: long (nullable = true)
#  |    |    |    |-- perk1Var1: long (nullable = true)
#  |    |    |    |-- perk1Var2: long (nullable = true)
#  |    |    |    |-- perk1Var3: long (nullable = true)
#  |    |    |    |-- perk2: long (nullable = true)
#  |    |    |    |-- perk2Var1: long (nullable = true)
#  |    |    |    |-- perk2Var2: long (nullable = true)
#  |    |    |    |-- perk2Var3: long (nullable = true)
#  |    |    |    |-- perk3: long (nullable = true)
#  |    |    |    |-- perk3Var1: long (nullable = true)
#  |    |    |    |-- perk3Var2: long (nullable = true)
#  |    |    |    |-- perk3Var3: long (nullable = true)
#  |    |    |    |-- perk4: long (nullable = true)
#  |    |    |    |-- perk4Var1: long (nullable = true)
#  |    |    |    |-- perk4Var2: long (nullable = true)
#  |    |    |    |-- perk4Var3: long (nullable = true)
#  |    |    |    |-- perk5: long (nullable = true)
#  |    |    |    |-- perk5Var1: long (nullable = true)
#  |    |    |    |-- perk5Var2: long (nullable = true)
#  |    |    |    |-- perk5Var3: long (nullable = true)
#  |    |    |    |-- perkPrimaryStyle: long (nullable = true)
#  |    |    |    |-- perkSubStyle: long (nullable = true)
#  |    |    |    |-- physicalDamageDealt: long (nullable = true)
#  |    |    |    |-- physicalDamageDealtToChampions: long (nullable = true)
#  |    |    |    |-- physicalDamageTaken: long (nullable = true)
#  |    |    |    |-- playerScore0: long (nullable = true)
#  |    |    |    |-- playerScore1: long (nullable = true)
#  |    |    |    |-- playerScore2: long (nullable = true)
#  |    |    |    |-- playerScore3: long (nullable = true)
#  |    |    |    |-- playerScore4: long (nullable = true)
#  |    |    |    |-- playerScore5: long (nullable = true)
#  |    |    |    |-- playerScore6: long (nullable = true)
#  |    |    |    |-- playerScore7: long (nullable = true)
#  |    |    |    |-- playerScore8: long (nullable = true)
#  |    |    |    |-- playerScore9: long (nullable = true)
#  |    |    |    |-- quadraKills: long (nullable = true)
#  |    |    |    |-- sightWardsBoughtInGame: long (nullable = true)
#  |    |    |    |-- statPerk0: long (nullable = true)
#  |    |    |    |-- statPerk1: long (nullable = true)
#  |    |    |    |-- statPerk2: long (nullable = true)
#  |    |    |    |-- timeCCingOthers: long (nullable = true)
#  |    |    |    |-- totalDamageDealt: long (nullable = true)
#  |    |    |    |-- totalDamageDealtToChampions: long (nullable = true)
#  |    |    |    |-- totalDamageTaken: long (nullable = true)
#  |    |    |    |-- totalHeal: long (nullable = true)
#  |    |    |    |-- totalMinionsKilled: long (nullable = true)
#  |    |    |    |-- totalPlayerScore: long (nullable = true)
#  |    |    |    |-- totalScoreRank: long (nullable = true)
#  |    |    |    |-- totalTimeCrowdControlDealt: long (nullable = true)
#  |    |    |    |-- totalUnitsHealed: long (nullable = true)
#  |    |    |    |-- tripleKills: long (nullable = true)
#  |    |    |    |-- trueDamageDealt: long (nullable = true)
#  |    |    |    |-- trueDamageDealtToChampions: long (nullable = true)
#  |    |    |    |-- trueDamageTaken: long (nullable = true)
#  |    |    |    |-- turretKills: long (nullable = true)
#  |    |    |    |-- unrealKills: long (nullable = true)
#  |    |    |    |-- visionScore: long (nullable = true)
#  |    |    |    |-- visionWardsBoughtInGame: long (nullable = true)
#  |    |    |    |-- wardsKilled: long (nullable = true)
#  |    |    |    |-- wardsPlaced: long (nullable = true)
#  |    |    |    |-- win: boolean (nullable = true)
#  |    |    |-- teamId: long (nullable = true)
#  |    |    |-- timeline: struct (nullable = true)
#  |    |    |    |-- creepsPerMinDeltas: struct (nullable = true)
#  |    |    |    |    |-- 0-10: double (nullable = true)
#  |    |    |    |    |-- 10-20: double (nullable = true)
#  |    |    |    |-- csDiffPerMinDeltas: struct (nullable = true)
#  |    |    |    |    |-- 0-10: double (nullable = true)
#  |    |    |    |    |-- 10-20: double (nullable = true)
#  |    |    |    |-- damageTakenDiffPerMinDeltas: struct (nullable = true)
#  |    |    |    |    |-- 0-10: double (nullable = true)
#  |    |    |    |    |-- 10-20: double (nullable = true)
#  |    |    |    |-- damageTakenPerMinDeltas: struct (nullable = true)
#  |    |    |    |    |-- 0-10: double (nullable = true)
#  |    |    |    |    |-- 10-20: double (nullable = true)
#  |    |    |    |-- goldPerMinDeltas: struct (nullable = true)
#  |    |    |    |    |-- 0-10: double (nullable = true)
#  |    |    |    |    |-- 10-20: double (nullable = true)
#  |    |    |    |-- lane: string (nullable = true)
#  |    |    |    |-- participantId: long (nullable = true)
#  |    |    |    |-- role: string (nullable = true)
#  |    |    |    |-- xpDiffPerMinDeltas: struct (nullable = true)
#  |    |    |    |    |-- 0-10: double (nullable = true)
#  |    |    |    |    |-- 10-20: double (nullable = true)
#  |    |    |    |-- xpPerMinDeltas: struct (nullable = true)
#  |    |    |    |    |-- 0-10: double (nullable = true)
#  |    |    |    |    |-- 10-20: double (nullable = true)
#  |    |-- info: struct (nullable = true)
#  |    |    |-- participantId: long (nullable = true)
#  |    |    |-- player: struct (nullable = true)
#  |    |    |    |-- accountId: string (nullable = true)
#  |    |    |    |-- currentAccountId: string (nullable = true)
#  |    |    |    |-- currentPlatformId: string (nullable = true)
#  |    |    |    |-- matchHistoryUri: string (nullable = true)
#  |    |    |    |-- platformId: string (nullable = true)
#  |    |    |    |-- profileIcon: long (nullable = true)
#  |    |    |    |-- summonerId: string (nullable = true)
#  |    |    |    |-- summonerName: string (nullable = true)

# %%
# flatten structs
match_data=flatten_df(match_data)
match_data.printSchema()
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- gameCreation: double (nullable = true)
#  |-- gameDuration: double (nullable = true)
#  |-- gameId: double (nullable = true)
#  |-- gameMode: string (nullable = true)
#  |-- gameType: string (nullable = true)
#  |-- gameVersion: string (nullable = true)
#  |-- mapId: double (nullable = true)
#  |-- platformId: string (nullable = true)
#  |-- queueId: double (nullable = true)
#  |-- seasonId: double (nullable = true)
#  |-- status_message: string (nullable = true)
#  |-- status_status_code: string (nullable = true)
#  |-- participants_info_info_participantId: long (nullable = true)
#  |-- participants_info_info_player_accountId: string (nullable = true)
#  |-- participants_info_info_player_currentAccountId: string (nullable = true)
#  |-- participants_info_info_player_currentPlatformId: string (nullable = true)
#  |-- participants_info_info_player_matchHistoryUri: string (nullable = true)
#  |-- participants_info_info_player_platformId: string (nullable = true)
#  |-- participants_info_info_player_profileIcon: long (nullable = true)
#  |-- participants_info_info_player_summonerId: string (nullable = true)
#  |-- participants_info_info_player_summonerName: string (nullable = true)
#  |-- participants_info_ids_championId: long (nullable = true)
#  |-- participants_info_ids_participantId: long (nullable = true)
#  |-- participants_info_ids_spell1Id: long (nullable = true)
#  |-- participants_info_ids_spell2Id: long (nullable = true)
#  |-- participants_info_ids_teamId: long (nullable = true)
#  |-- participants_info_ids_timeline_lane: string (nullable = true)
#  |-- participants_info_ids_timeline_participantId: long (nullable = true)
#  |-- participants_info_ids_timeline_role: string (nullable = true)
#  |-- participants_info_ids_timeline_xpPerMinDeltas_0-10: double (nullable = true)
#  |-- participants_info_ids_timeline_xpPerMinDeltas_10-20: double (nullable = true)
#  |-- participants_info_ids_timeline_xpDiffPerMinDeltas_0-10: double (nullable = true)
#  |-- participants_info_ids_timeline_xpDiffPerMinDeltas_10-20: double (nullable = true)
#  |-- participants_info_ids_timeline_goldPerMinDeltas_0-10: double (nullable = true)
#  |-- participants_info_ids_timeline_goldPerMinDeltas_10-20: double (nullable = true)
#  |-- participants_info_ids_timeline_damageTakenPerMinDeltas_0-10: double (nullable = true)
#  |-- participants_info_ids_timeline_damageTakenPerMinDeltas_10-20: double (nullable = true)
#  |-- participants_info_ids_timeline_damageTakenDiffPerMinDeltas_0-10: double (nullable = true)
#  |-- participants_info_ids_timeline_damageTakenDiffPerMinDeltas_10-20: double (nullable = true)
#  |-- participants_info_ids_timeline_csDiffPerMinDeltas_0-10: double (nullable = true)
#  |-- participants_info_ids_timeline_csDiffPerMinDeltas_10-20: double (nullable = true)
#  |-- participants_info_ids_timeline_creepsPerMinDeltas_0-10: double (nullable = true)
#  |-- participants_info_ids_timeline_creepsPerMinDeltas_10-20: double (nullable = true)
#  |-- participants_info_ids_stats_assists: long (nullable = true)
#  |-- participants_info_ids_stats_champLevel: long (nullable = true)
#  |-- participants_info_ids_stats_combatPlayerScore: long (nullable = true)
#  |-- participants_info_ids_stats_damageDealtToObjectives: long (nullable = true)
#  |-- participants_info_ids_stats_damageDealtToTurrets: long (nullable = true)
#  |-- participants_info_ids_stats_damageSelfMitigated: long (nullable = true)
#  |-- participants_info_ids_stats_deaths: long (nullable = true)
#  |-- participants_info_ids_stats_doubleKills: long (nullable = true)
#  |-- participants_info_ids_stats_firstBloodAssist: boolean (nullable = true)
#  |-- participants_info_ids_stats_firstBloodKill: boolean (nullable = true)
#  |-- participants_info_ids_stats_firstTowerAssist: boolean (nullable = true)
#  |-- participants_info_ids_stats_firstTowerKill: boolean (nullable = true)
#  |-- participants_info_ids_stats_goldEarned: long (nullable = true)
#  |-- participants_info_ids_stats_goldSpent: long (nullable = true)
#  |-- participants_info_ids_stats_inhibitorKills: long (nullable = true)
#  |-- participants_info_ids_stats_item0: long (nullable = true)
#  |-- participants_info_ids_stats_item1: long (nullable = true)
#  |-- participants_info_ids_stats_item2: long (nullable = true)
#  |-- participants_info_ids_stats_item3: long (nullable = true)
#  |-- participants_info_ids_stats_item4: long (nullable = true)
#  |-- participants_info_ids_stats_item5: long (nullable = true)
#  |-- participants_info_ids_stats_item6: long (nullable = true)
#  |-- participants_info_ids_stats_killingSprees: long (nullable = true)
#  |-- participants_info_ids_stats_kills: long (nullable = true)
#  |-- participants_info_ids_stats_largestCriticalStrike: long (nullable = true)
#  |-- participants_info_ids_stats_largestKillingSpree: long (nullable = true)
#  |-- participants_info_ids_stats_largestMultiKill: long (nullable = true)
#  |-- participants_info_ids_stats_longestTimeSpentLiving: long (nullable = true)
#  |-- participants_info_ids_stats_magicDamageDealt: long (nullable = true)
#  |-- participants_info_ids_stats_magicDamageDealtToChampions: long (nullable = true)
#  |-- participants_info_ids_stats_magicalDamageTaken: long (nullable = true)
#  |-- participants_info_ids_stats_neutralMinionsKilled: long (nullable = true)
#  |-- participants_info_ids_stats_neutralMinionsKilledEnemyJungle: long (nullable = true)
#  |-- participants_info_ids_stats_neutralMinionsKilledTeamJungle: long (nullable = true)
#  |-- participants_info_ids_stats_objectivePlayerScore: long (nullable = true)
#  |-- participants_info_ids_stats_participantId: long (nullable = true)
#  |-- participants_info_ids_stats_pentaKills: long (nullable = true)
#  |-- participants_info_ids_stats_perk0: long (nullable = true)
#  |-- participants_info_ids_stats_perk0Var1: long (nullable = true)
#  |-- participants_info_ids_stats_perk0Var2: long (nullable = true)
#  |-- participants_info_ids_stats_perk0Var3: long (nullable = true)
#  |-- participants_info_ids_stats_perk1: long (nullable = true)
#  |-- participants_info_ids_stats_perk1Var1: long (nullable = true)
#  |-- participants_info_ids_stats_perk1Var2: long (nullable = true)
#  |-- participants_info_ids_stats_perk1Var3: long (nullable = true)
#  |-- participants_info_ids_stats_perk2: long (nullable = true)
#  |-- participants_info_ids_stats_perk2Var1: long (nullable = true)
#  |-- participants_info_ids_stats_perk2Var2: long (nullable = true)
#  |-- participants_info_ids_stats_perk2Var3: long (nullable = true)
#  |-- participants_info_ids_stats_perk3: long (nullable = true)
#  |-- participants_info_ids_stats_perk3Var1: long (nullable = true)
#  |-- participants_info_ids_stats_perk3Var2: long (nullable = true)
#  |-- participants_info_ids_stats_perk3Var3: long (nullable = true)
#  |-- participants_info_ids_stats_perk4: long (nullable = true)
#  |-- participants_info_ids_stats_perk4Var1: long (nullable = true)
#  |-- participants_info_ids_stats_perk4Var2: long (nullable = true)
#  |-- participants_info_ids_stats_perk4Var3: long (nullable = true)
#  |-- participants_info_ids_stats_perk5: long (nullable = true)
#  |-- participants_info_ids_stats_perk5Var1: long (nullable = true)
#  |-- participants_info_ids_stats_perk5Var2: long (nullable = true)
#  |-- participants_info_ids_stats_perk5Var3: long (nullable = true)
#  |-- participants_info_ids_stats_perkPrimaryStyle: long (nullable = true)
#  |-- participants_info_ids_stats_perkSubStyle: long (nullable = true)
#  |-- participants_info_ids_stats_physicalDamageDealt: long (nullable = true)
#  |-- participants_info_ids_stats_physicalDamageDealtToChampions: long (nullable = true)
#  |-- participants_info_ids_stats_physicalDamageTaken: long (nullable = true)
#  |-- participants_info_ids_stats_playerScore0: long (nullable = true)
#  |-- participants_info_ids_stats_playerScore1: long (nullable = true)
#  |-- participants_info_ids_stats_playerScore2: long (nullable = true)
#  |-- participants_info_ids_stats_playerScore3: long (nullable = true)
#  |-- participants_info_ids_stats_playerScore4: long (nullable = true)
#  |-- participants_info_ids_stats_playerScore5: long (nullable = true)
#  |-- participants_info_ids_stats_playerScore6: long (nullable = true)
#  |-- participants_info_ids_stats_playerScore7: long (nullable = true)
#  |-- participants_info_ids_stats_playerScore8: long (nullable = true)
#  |-- participants_info_ids_stats_playerScore9: long (nullable = true)
#  |-- participants_info_ids_stats_quadraKills: long (nullable = true)
#  |-- participants_info_ids_stats_sightWardsBoughtInGame: long (nullable = true)
#  |-- participants_info_ids_stats_statPerk0: long (nullable = true)
#  |-- participants_info_ids_stats_statPerk1: long (nullable = true)
#  |-- participants_info_ids_stats_statPerk2: long (nullable = true)
#  |-- participants_info_ids_stats_timeCCingOthers: long (nullable = true)
#  |-- participants_info_ids_stats_totalDamageDealt: long (nullable = true)
#  |-- participants_info_ids_stats_totalDamageDealtToChampions: long (nullable = true)
#  |-- participants_info_ids_stats_totalDamageTaken: long (nullable = true)
#  |-- participants_info_ids_stats_totalHeal: long (nullable = true)
#  |-- participants_info_ids_stats_totalMinionsKilled: long (nullable = true)
#  |-- participants_info_ids_stats_totalPlayerScore: long (nullable = true)
#  |-- participants_info_ids_stats_totalScoreRank: long (nullable = true)
#  |-- participants_info_ids_stats_totalTimeCrowdControlDealt: long (nullable = true)
#  |-- participants_info_ids_stats_totalUnitsHealed: long (nullable = true)
#  |-- participants_info_ids_stats_tripleKills: long (nullable = true)
#  |-- participants_info_ids_stats_trueDamageDealt: long (nullable = true)
#  |-- participants_info_ids_stats_trueDamageDealtToChampions: long (nullable = true)
#  |-- participants_info_ids_stats_trueDamageTaken: long (nullable = true)
#  |-- participants_info_ids_stats_turretKills: long (nullable = true)
#  |-- participants_info_ids_stats_unrealKills: long (nullable = true)
#  |-- participants_info_ids_stats_visionScore: long (nullable = true)
#  |-- participants_info_ids_stats_visionWardsBoughtInGame: long (nullable = true)
#  |-- participants_info_ids_stats_wardsKilled: long (nullable = true)
#  |-- participants_info_ids_stats_wardsPlaced: long (nullable = true)
#  |-- participants_info_ids_stats_win: boolean (nullable = true)

# %%
itens_dict = itens.select("item_id", "name").distinct().collect()
itens_dict = {v["item_id"]:v["name"] for v in itens_dict}

# %%
champions_dict = champions.select("key", "name").distinct().collect()
champions_dict = {v["key"]:v["name"] for v in champions_dict}

# %%
def transform(x):
    try:
        value = itens_dict[int(x)] 
    except:
        value = "Name Not Found"
    return value


new_cols_itens = udf(lambda x : transform(x), StringType())

# %%
match_data = match_data.withColumn("name_item0", new_cols_itens(col("participants_info_ids_stats_item0")))
match_data = match_data.withColumn("name_item1", new_cols_itens(col("participants_info_ids_stats_item1")))
match_data = match_data.withColumn("name_item2", new_cols_itens(col("participants_info_ids_stats_item2")))
match_data = match_data.withColumn("name_item3", new_cols_itens(col("participants_info_ids_stats_item3")))
match_data = match_data.withColumn("name_item4", new_cols_itens(col("participants_info_ids_stats_item4")))
match_data = match_data.withColumn("name_item5", new_cols_itens(col("participants_info_ids_stats_item5")))
match_data = match_data.withColumn("name_item6", new_cols_itens(col("participants_info_ids_stats_item6")))

# %%
def transform_champions(x):
    try:
        value = champions_dict[int(x)] 
    except:
        value = "Name Not Found"
    return value


new_cols_champions = udf(lambda x : transform_champions(x), StringType())

match_data = match_data.withColumn("name_champion", new_cols_champions(col("participants_info_ids_championId")))

# %%
match_data.select("name_champion").head(4)
# Out:
# [Row(name_champion='LeBlanc'),
#  Row(name_champion='Olaf'),
#  Row(name_champion='Kalista'),
#  Row(name_champion='Shen')]

# %% [markdown]
# # Merge DataFrames

# %%
winner = match_data.join(winner, on=['gameId'], how='inner')
loser = match_data.join(loser, on=['gameId'], how='inner')

# %%
winner.printSchema()
# Out:
# root
#  |-- gameId: double (nullable = true)
#  |-- _c0: integer (nullable = true)
#  |-- gameCreation: double (nullable = true)
#  |-- gameDuration: double (nullable = true)
#  |-- gameMode: string (nullable = true)
#  |-- gameType: string (nullable = true)
#  |-- gameVersion: string (nullable = true)
#  |-- mapId: double (nullable = true)
#  |-- platformId: string (nullable = true)
#  |-- queueId: double (nullable = true)
#  |-- seasonId: double (nullable = true)
#  |-- status_message: string (nullable = true)
#  |-- status_status_code: string (nullable = true)
#  |-- participants_info_info_participantId: long (nullable = true)
#  |-- participants_info_info_player_accountId: string (nullable = true)
#  |-- participants_info_info_player_currentAccountId: string (nullable = true)
#  |-- participants_info_info_player_currentPlatformId: string (nullable = true)
#  |-- participants_info_info_player_matchHistoryUri: string (nullable = true)
#  |-- participants_info_info_player_platformId: string (nullable = true)
#  |-- participants_info_info_player_profileIcon: long (nullable = true)
#  |-- participants_info_info_player_summonerId: string (nullable = true)
#  |-- participants_info_info_player_summonerName: string (nullable = true)
#  |-- participants_info_ids_championId: long (nullable = true)
#  |-- participants_info_ids_participantId: long (nullable = true)
#  |-- participants_info_ids_spell1Id: long (nullable = true)
#  |-- participants_info_ids_spell2Id: long (nullable = true)
#  |-- participants_info_ids_teamId: long (nullable = true)
#  |-- participants_info_ids_timeline_lane: string (nullable = true)
#  |-- participants_info_ids_timeline_participantId: long (nullable = true)
#  |-- participants_info_ids_timeline_role: string (nullable = true)
#  |-- participants_info_ids_timeline_xpPerMinDeltas_0-10: double (nullable = true)
#  |-- participants_info_ids_timeline_xpPerMinDeltas_10-20: double (nullable = true)
#  |-- participants_info_ids_timeline_xpDiffPerMinDeltas_0-10: double (nullable = true)
#  |-- participants_info_ids_timeline_xpDiffPerMinDeltas_10-20: double (nullable = true)
#  |-- participants_info_ids_timeline_goldPerMinDeltas_0-10: double (nullable = true)
#  |-- participants_info_ids_timeline_goldPerMinDeltas_10-20: double (nullable = true)
#  |-- participants_info_ids_timeline_damageTakenPerMinDeltas_0-10: double (nullable = true)
#  |-- participants_info_ids_timeline_damageTakenPerMinDeltas_10-20: double (nullable = true)
#  |-- participants_info_ids_timeline_damageTakenDiffPerMinDeltas_0-10: double (nullable = true)
#  |-- participants_info_ids_timeline_damageTakenDiffPerMinDeltas_10-20: double (nullable = true)
#  |-- participants_info_ids_timeline_csDiffPerMinDeltas_0-10: double (nullable = true)
#  |-- participants_info_ids_timeline_csDiffPerMinDeltas_10-20: double (nullable = true)
#  |-- participants_info_ids_timeline_creepsPerMinDeltas_0-10: double (nullable = true)
#  |-- participants_info_ids_timeline_creepsPerMinDeltas_10-20: double (nullable = true)
#  |-- participants_info_ids_stats_assists: long (nullable = true)
#  |-- participants_info_ids_stats_champLevel: long (nullable = true)
#  |-- participants_info_ids_stats_combatPlayerScore: long (nullable = true)
#  |-- participants_info_ids_stats_damageDealtToObjectives: long (nullable = true)
#  |-- participants_info_ids_stats_damageDealtToTurrets: long (nullable = true)
#  |-- participants_info_ids_stats_damageSelfMitigated: long (nullable = true)
#  |-- participants_info_ids_stats_deaths: long (nullable = true)
#  |-- participants_info_ids_stats_doubleKills: long (nullable = true)
#  |-- participants_info_ids_stats_firstBloodAssist: boolean (nullable = true)
#  |-- participants_info_ids_stats_firstBloodKill: boolean (nullable = true)
#  |-- participants_info_ids_stats_firstTowerAssist: boolean (nullable = true)
#  |-- participants_info_ids_stats_firstTowerKill: boolean (nullable = true)
#  |-- participants_info_ids_stats_goldEarned: long (nullable = true)
#  |-- participants_info_ids_stats_goldSpent: long (nullable = true)
#  |-- participants_info_ids_stats_inhibitorKills: long (nullable = true)
#  |-- participants_info_ids_stats_item0: long (nullable = true)
#  |-- participants_info_ids_stats_item1: long (nullable = true)
#  |-- participants_info_ids_stats_item2: long (nullable = true)
#  |-- participants_info_ids_stats_item3: long (nullable = true)
#  |-- participants_info_ids_stats_item4: long (nullable = true)
#  |-- participants_info_ids_stats_item5: long (nullable = true)
#  |-- participants_info_ids_stats_item6: long (nullable = true)
#  |-- participants_info_ids_stats_killingSprees: long (nullable = true)
#  |-- participants_info_ids_stats_kills: long (nullable = true)
#  |-- participants_info_ids_stats_largestCriticalStrike: long (nullable = true)
#  |-- participants_info_ids_stats_largestKillingSpree: long (nullable = true)
#  |-- participants_info_ids_stats_largestMultiKill: long (nullable = true)
#  |-- participants_info_ids_stats_longestTimeSpentLiving: long (nullable = true)
#  |-- participants_info_ids_stats_magicDamageDealt: long (nullable = true)
#  |-- participants_info_ids_stats_magicDamageDealtToChampions: long (nullable = true)
#  |-- participants_info_ids_stats_magicalDamageTaken: long (nullable = true)
#  |-- participants_info_ids_stats_neutralMinionsKilled: long (nullable = true)
#  |-- participants_info_ids_stats_neutralMinionsKilledEnemyJungle: long (nullable = true)
#  |-- participants_info_ids_stats_neutralMinionsKilledTeamJungle: long (nullable = true)
#  |-- participants_info_ids_stats_objectivePlayerScore: long (nullable = true)
#  |-- participants_info_ids_stats_participantId: long (nullable = true)
#  |-- participants_info_ids_stats_pentaKills: long (nullable = true)
#  |-- participants_info_ids_stats_perk0: long (nullable = true)
#  |-- participants_info_ids_stats_perk0Var1: long (nullable = true)
#  |-- participants_info_ids_stats_perk0Var2: long (nullable = true)
#  |-- participants_info_ids_stats_perk0Var3: long (nullable = true)
#  |-- participants_info_ids_stats_perk1: long (nullable = true)
#  |-- participants_info_ids_stats_perk1Var1: long (nullable = true)
#  |-- participants_info_ids_stats_perk1Var2: long (nullable = true)
#  |-- participants_info_ids_stats_perk1Var3: long (nullable = true)
#  |-- participants_info_ids_stats_perk2: long (nullable = true)
#  |-- participants_info_ids_stats_perk2Var1: long (nullable = true)
#  |-- participants_info_ids_stats_perk2Var2: long (nullable = true)
#  |-- participants_info_ids_stats_perk2Var3: long (nullable = true)
#  |-- participants_info_ids_stats_perk3: long (nullable = true)
#  |-- participants_info_ids_stats_perk3Var1: long (nullable = true)
#  |-- participants_info_ids_stats_perk3Var2: long (nullable = true)
#  |-- participants_info_ids_stats_perk3Var3: long (nullable = true)
#  |-- participants_info_ids_stats_perk4: long (nullable = true)
#  |-- participants_info_ids_stats_perk4Var1: long (nullable = true)
#  |-- participants_info_ids_stats_perk4Var2: long (nullable = true)
#  |-- participants_info_ids_stats_perk4Var3: long (nullable = true)
#  |-- participants_info_ids_stats_perk5: long (nullable = true)
#  |-- participants_info_ids_stats_perk5Var1: long (nullable = true)
#  |-- participants_info_ids_stats_perk5Var2: long (nullable = true)
#  |-- participants_info_ids_stats_perk5Var3: long (nullable = true)
#  |-- participants_info_ids_stats_perkPrimaryStyle: long (nullable = true)
#  |-- participants_info_ids_stats_perkSubStyle: long (nullable = true)
#  |-- participants_info_ids_stats_physicalDamageDealt: long (nullable = true)
#  |-- participants_info_ids_stats_physicalDamageDealtToChampions: long (nullable = true)
#  |-- participants_info_ids_stats_physicalDamageTaken: long (nullable = true)
#  |-- participants_info_ids_stats_playerScore0: long (nullable = true)
#  |-- participants_info_ids_stats_playerScore1: long (nullable = true)
#  |-- participants_info_ids_stats_playerScore2: long (nullable = true)
#  |-- participants_info_ids_stats_playerScore3: long (nullable = true)
#  |-- participants_info_ids_stats_playerScore4: long (nullable = true)
#  |-- participants_info_ids_stats_playerScore5: long (nullable = true)
#  |-- participants_info_ids_stats_playerScore6: long (nullable = true)
#  |-- participants_info_ids_stats_playerScore7: long (nullable = true)
#  |-- participants_info_ids_stats_playerScore8: long (nullable = true)
#  |-- participants_info_ids_stats_playerScore9: long (nullable = true)
#  |-- participants_info_ids_stats_quadraKills: long (nullable = true)
#  |-- participants_info_ids_stats_sightWardsBoughtInGame: long (nullable = true)
#  |-- participants_info_ids_stats_statPerk0: long (nullable = true)
#  |-- participants_info_ids_stats_statPerk1: long (nullable = true)
#  |-- participants_info_ids_stats_statPerk2: long (nullable = true)
#  |-- participants_info_ids_stats_timeCCingOthers: long (nullable = true)
#  |-- participants_info_ids_stats_totalDamageDealt: long (nullable = true)
#  |-- participants_info_ids_stats_totalDamageDealtToChampions: long (nullable = true)
#  |-- participants_info_ids_stats_totalDamageTaken: long (nullable = true)
#  |-- participants_info_ids_stats_totalHeal: long (nullable = true)
#  |-- participants_info_ids_stats_totalMinionsKilled: long (nullable = true)
#  |-- participants_info_ids_stats_totalPlayerScore: long (nullable = true)
#  |-- participants_info_ids_stats_totalScoreRank: long (nullable = true)
#  |-- participants_info_ids_stats_totalTimeCrowdControlDealt: long (nullable = true)
#  |-- participants_info_ids_stats_totalUnitsHealed: long (nullable = true)
#  |-- participants_info_ids_stats_tripleKills: long (nullable = true)
#  |-- participants_info_ids_stats_trueDamageDealt: long (nullable = true)
#  |-- participants_info_ids_stats_trueDamageDealtToChampions: long (nullable = true)
#  |-- participants_info_ids_stats_trueDamageTaken: long (nullable = true)
#  |-- participants_info_ids_stats_turretKills: long (nullable = true)
#  |-- participants_info_ids_stats_unrealKills: long (nullable = true)
#  |-- participants_info_ids_stats_visionScore: long (nullable = true)
#  |-- participants_info_ids_stats_visionWardsBoughtInGame: long (nullable = true)
#  |-- participants_info_ids_stats_wardsKilled: long (nullable = true)
#  |-- participants_info_ids_stats_wardsPlaced: long (nullable = true)
#  |-- participants_info_ids_stats_win: boolean (nullable = true)
#  |-- name_item0: string (nullable = true)
#  |-- name_item1: string (nullable = true)
#  |-- name_item2: string (nullable = true)
#  |-- name_item3: string (nullable = true)
#  |-- name_item4: string (nullable = true)
#  |-- name_item5: string (nullable = true)
#  |-- name_item6: string (nullable = true)
#  |-- name_champion: string (nullable = true)
#  |-- _c0: integer (nullable = true)
#  |-- teamId: integer (nullable = true)
#  |-- win: string (nullable = true)
#  |-- firstBlood: boolean (nullable = true)
#  |-- firstTower: boolean (nullable = true)
#  |-- firstInhibitor: boolean (nullable = true)
#  |-- firstBaron: boolean (nullable = true)
#  |-- firstDragon: boolean (nullable = true)
#  |-- firstRiftHerald: boolean (nullable = true)
#  |-- towerKills: integer (nullable = true)
#  |-- inhibitorKills: integer (nullable = true)
#  |-- baronKills: integer (nullable = true)
#  |-- dragonKills: integer (nullable = true)
#  |-- vilemawKills: integer (nullable = true)
#  |-- riftHeraldKills: integer (nullable = true)
#  |-- dominionVictoryScore: integer (nullable = true)
#  |-- bans_championId1: long (nullable = true)
#  |-- bans_championId2: long (nullable = true)
#  |-- bans_championId3: long (nullable = true)
#  |-- bans_championId4: long (nullable = true)
#  |-- bans_championId5: long (nullable = true)

# %%
# Register the DataFrame as a SQL temporary view
match_data.createOrReplaceTempView("match_data")
winner.createOrReplaceTempView("winner")
loser.createOrReplaceTempView("loser")

# %%
players = sqlContext.sql("""
                            SELECT victorys.id as user, victorys.championId as champion_id, victorys.won_matches, matches.total_matches, victorys.won_matches/matches.total_matches as win_rate \
                            FROM \
                                (SELECT match_data.participants_info_info_player_accountId as id, match_data.participants_info_ids_championId as championID, COUNT(DISTINCT(match_data.gameId)) as won_matches \
                                FROM match_data \
                                WHERE match_data.participants_info_ids_stats_win == true \
                                GROUP BY match_data.participants_info_info_player_accountId, match_data.participants_info_ids_championId) as victorys \
                            LEFT JOIN (SELECT match_data.participants_info_info_player_accountId as id, match_data.participants_info_ids_championId as championID, COUNT(DISTINCT(match_data.gameId)) as total_matches \
                                       FROM match_data \
                                       GROUP BY match_data.participants_info_info_player_accountId, match_data.participants_info_ids_championId) as matches \
                            ON victorys.id=matches.id AND victorys.championID = matches.championID
                            ORDER BY matches.total_matches DESC
                        """) 
players.createOrReplaceTempView("players")
players.show()
# Out:
# +--------------------+-----------+-----------+-------------+-------------------+
# |                user|champion_id|won_matches|total_matches|           win_rate|
# +--------------------+-----------+-----------+-------------+-------------------+
# |Kre-yBBl_dth1hTu8...|        245|         21|           43| 0.4883720930232558|
# |qTg_APziIefWzPLf9...|         12|         24|           41| 0.5853658536585366|
# |HO0Zipwm_4RS7iUAX...|        104|         23|           40|              0.575|
# |k1clnQm6WYzfh-3jD...|        154|         18|           37| 0.4864864864864865|
# |Dli4ZNwRdA8FOkKO-...|         34|         12|           35|0.34285714285714286|
# |-K5Dcqaa_SYxpKQUG...|        555|         14|           35|                0.4|
# |5VLbcHCjOrxiV5EVj...|        245|         20|           35| 0.5714285714285714|
# |t_cBLaPpqGjJHZn-T...|        119|         16|           35|0.45714285714285713|
# |QDzzlcKqSQPsU1j4F...|         69|         20|           31| 0.6451612903225806|
# |eUEOhQpye02aeTnO-...|         24|         17|           30| 0.5666666666666667|
# |216vFToXBjDoqC3B-...|         38|         11|           30|0.36666666666666664|
# |-u4kXe673sDydgAG2...|         40|         15|           30|                0.5|
# |AiWgtCM4zWhXEFXBd...|         29|         13|           29| 0.4482758620689655|
# |SFLpkmF1KsDp5P9FY...|        154|         19|           29| 0.6551724137931034|
# |IxvcuNZ_YzKnWy-eF...|         98|         16|           29| 0.5517241379310345|
# |alEJ6dwgbWnPqNuNT...|        203|         17|           28| 0.6071428571428571|
# |kWvZcs0hfQkGfoROD...|         86|         18|           28| 0.6428571428571429|
# |zBSqg-y06v_Touc8X...|         33|          8|           27| 0.2962962962962963|
# |dBCC_W1jTA_-QplOR...|        238|         11|           27| 0.4074074074074074|
# |UGafMq9t_rfthy-tq...|         55|         16|           27| 0.5925925925925926|
# +--------------------+-----------+-----------+-------------+-------------------+
# only showing top 20 rows

# %%
connector = "-"
build = sqlContext.sql("""
                          SELECT build.championName, build.build_name, COUNT(build.build_name) as total_matches \
                          FROM \
                              (SELECT match_data.name_champion as championName, CONCAT(match_data.name_item0, "%s",
                                             match_data.name_item1, "%s",
                                             match_data.name_item2, "%s",
                                             match_data.name_item3, "%s",
                                             match_data.name_item4, "%s",
                                             match_data.name_item5, "%s",
                                             match_data.name_item6) as build_name \
                              FROM match_data \
                              WHERE match_data.participants_info_ids_stats_item0 IS NOT NULL \
                              AND match_data.participants_info_ids_stats_item1 IS NOT NULL
                              AND match_data.participants_info_ids_stats_item2 IS NOT NULL
                              AND match_data.participants_info_ids_stats_item3 IS NOT NULL
                              AND match_data.participants_info_ids_stats_item4 IS NOT NULL
                              AND match_data.participants_info_ids_stats_item5 IS NOT NULL
                              AND match_data.participants_info_ids_stats_item6 IS NOT NULL
                              AND match_data.participants_info_ids_stats_item0 != 0
                              AND match_data.participants_info_ids_stats_item1 != 0
                              AND match_data.participants_info_ids_stats_item2 != 0
                              AND match_data.participants_info_ids_stats_item3 != 0
                              AND match_data.participants_info_ids_stats_item4 != 0
                              AND match_data.participants_info_ids_stats_item5 != 0
                              AND match_data.participants_info_ids_stats_item6 != 0
                              AND match_data.participants_info_info_player_accountId 
                              IN ( \
                                   SELECT players.user
                                   FROM players \
                                   WHERE players.win_rate > 0.5 AND players.total_matches > 5)) as build \
                         GROUP BY build.championName, build.build_name \
                         ORDER BY total DESC
                    """ % tuple([connector]*6))
build.show()
# Out:
# +--------------------------+--------------------+-----+
# |first(championName, false)|          build_name|total|
# +--------------------------+--------------------+-----+
# |                     Janna|Boots of Mobility...|    3|
# |                     Janna|Boots of Swiftnes...|    3|
# |                     Jayce|Corrupting Potion...|    2|
# |                  Pantheon|Ninja Tabi-Youmuu...|    2|
# |                      Pyke|Runesteel Spaulde...|    2|
# |                    Illaoi|Black Cleaver-Cor...|    2|
# |                  Pantheon|Knight's Vow-Brok...|    2|
# |                     Elise|Enchantment: Runi...|    2|
# |                       Jax|Trinity Force-Bil...|    2|
# |                      Fizz|Corrupting Potion...|    2|
# |                     Talon|Tiamat-Youmuu's G...|    2|
# |                Blitzcrank|Pauldrons of Whit...|    2|
# |                      Fizz|Sheen-Zhonya's Ho...|    2|
# |                      Ahri|Hextech GLP-800-B...|    2|
# |                      Pyke|Youmuu's Ghostbla...|    2|
# |                   Rek'Sai|Control Ward-Ruby...|    2|
# |                    Irelia|Black Cleaver-Wit...|    2|
# |                     Talon|Tiamat-Control Wa...|    2|
# |                     Shaco|Ruby Crystal-Shar...|    2|
# |                  Nautilus|Gargoyle Stonepla...|    2|
# +--------------------------+--------------------+-----+
# only showing top 20 rows
